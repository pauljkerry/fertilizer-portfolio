# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import optuna

sys.path.append(os.path.abspath(".."))

import src.models.xgb.xgb_optuna_optimizer as op
import src.models.xgb.xgb_cv_trainer as cv

# %%
# データの読み込み
env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=env_path)
url = os.environ.get("OPTUNA_STORAGE_URL")

tr_df4 = pd.read_csv("../artifacts/features/tr_df4.csv")
test_df4 = pd.read_csv("../artifacts/features/test_df4.csv")

cat_cols = [
    "Tem", "Hum", "Moi", "N", "K", "P", "Soil", "Crop"
]

# %%
# tr_df4 eta 0.02のrandom探索→TPE探索
# eta 0.1 のbest paramsの取得
best_params = {
    "max_depth": 8,
    "min_child_weight": 29.803558296988122,
    "colsample_bytree": 0.3970689908418626,
    "subsample": 0.856532598287343,
    "reg_alpha": 9.002010481036006,
    "reg_lambda": 0.004363285541408288
}

objective = op.create_objective(
    tr_df4,
    early_stopping_rounds=500,
    tree_method="gpu_hist",
    n_jobs=10,
    cat_cols=cat_cols
)

random_sampler = optuna.samplers.RandomSampler(seed=42)

op.run_optuna_search(
    objective,
    n_trials=1,
    n_jobs=1,
    study_name="xgb_v4.1",
    storage=url,
    initial_params=best_params
)
# Out:
# [I 2025-07-12 14:46:26,772] Using an existing study with name 'xgb_v4.1' instead of creating a new one.
#   0%|          | 0/1 [00:00<?, ?it/s]
# [0]	train-map@3:0.30832	eval-map@3:0.29452
# [100]	train-map@3:0.35338	eval-map@3:0.32591
# [200]	train-map@3:0.36443	eval-map@3:0.33122
# [300]	train-map@3:0.37450	eval-map@3:0.33485
# [400]	train-map@3:0.38393	eval-map@3:0.33801
# [500]	train-map@3:0.39284	eval-map@3:0.34143
# [600]	train-map@3:0.40138	eval-map@3:0.34408
# [700]	train-map@3:0.40998	eval-map@3:0.34669
# [800]	train-map@3:0.41757	eval-map@3:0.34941
# [900]	train-map@3:0.42496	eval-map@3:0.35173
# [1000]	train-map@3:0.43178	eval-map@3:0.35385
# [1100]	train-map@3:0.43788	eval-map@3:0.35578
# [1200]	train-map@3:0.44386	eval-map@3:0.35717
# [1300]	train-map@3:0.44927	eval-map@3:0.35839
# [1400]	train-map@3:0.45420	eval-map@3:0.35971
# [1500]	train-map@3:0.45874	eval-map@3:0.36083
# [1600]	train-map@3:0.46290	eval-map@3:0.36188
# [1700]	train-map@3:0.46688	eval-map@3:0.36273
# [1800]	train-map@3:0.47038	eval-map@3:0.36334
# [1900]	train-map@3:0.47386	eval-map@3:0.36418
# [2000]	train-map@3:0.47700	eval-map@3:0.36457
# [2100]	train-map@3:0.48011	eval-map@3:0.36532
# [2200]	train-map@3:0.48308	eval-map@3:0.36570
# [2300]	train-map@3:0.48577	eval-map@3:0.36595
# [2400]	train-map@3:0.48818	eval-map@3:0.36656
# [2500]	train-map@3:0.49063	eval-map@3:0.36686
# [2600]	train-map@3:0.49296	eval-map@3:0.36727
# [2700]	train-map@3:0.49512	eval-map@3:0.36755
# [2800]	train-map@3:0.49718	eval-map@3:0.36778
# [2900]	train-map@3:0.49951	eval-map@3:0.36781
# [3000]	train-map@3:0.50154	eval-map@3:0.36802
# [3100]	train-map@3:0.50335	eval-map@3:0.36819
# [3200]	train-map@3:0.50506	eval-map@3:0.36843
# [3300]	train-map@3:0.50706	eval-map@3:0.36839
# [3400]	train-map@3:0.50879	eval-map@3:0.36854
# [3500]	train-map@3:0.51051	eval-map@3:0.36869
# [3600]	train-map@3:0.51207	eval-map@3:0.36869
# [3700]	train-map@3:0.51371	eval-map@3:0.36883
# [3800]	train-map@3:0.51516	eval-map@3:0.36873
# [3900]	train-map@3:0.51660	eval-map@3:0.36893
# [4000]	train-map@3:0.51799	eval-map@3:0.36888
# [4100]	train-map@3:0.51950	eval-map@3:0.36895
# [4200]	train-map@3:0.52084	eval-map@3:0.36916
# [4300]	train-map@3:0.52218	eval-map@3:0.36907
# [4400]	train-map@3:0.52356	eval-map@3:0.36897
# [4500]	train-map@3:0.52491	eval-map@3:0.36928
# [4600]	train-map@3:0.52611	eval-map@3:0.36933
# [4700]	train-map@3:0.52740	eval-map@3:0.36917
# [4800]	train-map@3:0.52857	eval-map@3:0.36902
# [4900]	train-map@3:0.52979	eval-map@3:0.36925
# [4999]	train-map@3:0.53100	eval-map@3:0.36908
# Training time: 01:16:12
# Train map@3: 0.52630
# Valid map@3: 0.36947
# [I 2025-07-12 16:02:39,938] Trial 3 finished with value: 0.36947 and parameters: {'max_depth': 8, 'min_child_weight': 29.803558296988122, 'colsample_bytree': 0.3970689908418626, 'subsample': 0.856532598287343, 'reg_alpha': 9.002010481036006, 'reg_lambda': 0.004363285541408288}. Best is trial 3 with value: 0.36947.

# %%
# ID19のfull train
params = {
    "max_depth": 8,
    "min_child_weight": 29.803558296988122,
    "colsample_bytree": 0.3970689908418626,
    "subsample": 0.856532598287343,
    "reg_alpha": 9.002010481036006,
    "reg_lambda": 0.004363285541408288,
    "learning_rate": 0.02
}

trainer = cv.XGBCVTrainer(params=params, cat_cols=cat_cols)
trainer.full_train(tr_df4, test_df4, 4613, 19)
# Out:
# Training time: 00:06:44
# Successfully saved test predictions to ../artifacts/test_preds/full/test_full_19.npy

# %%
trainer = cv.XGBCVTrainer(params=params, cat_cols=cat_cols)
oof_preds, test_preds = trainer.fit(tr_df4, test_df4)
# Out:
# Fold 1
# [0]	train-map@3:0.30832	eval-map@3:0.29452
# [100]	train-map@3:0.35338	eval-map@3:0.32591
# [200]	train-map@3:0.36443	eval-map@3:0.33122
# [300]	train-map@3:0.37450	eval-map@3:0.33485
# [400]	train-map@3:0.38393	eval-map@3:0.33801
# [500]	train-map@3:0.39284	eval-map@3:0.34143
# [600]	train-map@3:0.40138	eval-map@3:0.34408
# [700]	train-map@3:0.40998	eval-map@3:0.34669
# [800]	train-map@3:0.41757	eval-map@3:0.34941
# [900]	train-map@3:0.42496	eval-map@3:0.35173
# [1000]	train-map@3:0.43178	eval-map@3:0.35385
# [1100]	train-map@3:0.43788	eval-map@3:0.35578
# [1200]	train-map@3:0.44386	eval-map@3:0.35717
# [1300]	train-map@3:0.44927	eval-map@3:0.35839
# [1400]	train-map@3:0.45420	eval-map@3:0.35971
# [1500]	train-map@3:0.45874	eval-map@3:0.36083
# [1600]	train-map@3:0.46290	eval-map@3:0.36188
# [1700]	train-map@3:0.46688	eval-map@3:0.36273
# [1800]	train-map@3:0.47038	eval-map@3:0.36334
# [1900]	train-map@3:0.47386	eval-map@3:0.36418
# [2000]	train-map@3:0.47700	eval-map@3:0.36457
# [2100]	train-map@3:0.48011	eval-map@3:0.36532
# [2200]	train-map@3:0.48308	eval-map@3:0.36570
# [2300]	train-map@3:0.48577	eval-map@3:0.36595
# [2400]	train-map@3:0.48818	eval-map@3:0.36656
# [2500]	train-map@3:0.49063	eval-map@3:0.36686
# [2600]	train-map@3:0.49296	eval-map@3:0.36727
# [2700]	train-map@3:0.49512	eval-map@3:0.36755
# [2800]	train-map@3:0.49718	eval-map@3:0.36778
# [2900]	train-map@3:0.49951	eval-map@3:0.36781
# [3000]	train-map@3:0.50154	eval-map@3:0.36802
# [3100]	train-map@3:0.50335	eval-map@3:0.36819
# [3200]	train-map@3:0.50506	eval-map@3:0.36843
# [3300]	train-map@3:0.50706	eval-map@3:0.36839
# [3355]	train-map@3:0.50804	eval-map@3:0.36849
# Training time: 00:53:28
# Train map@3: 0.50619
# Valid map@3: 0.36853
#
# Fold 2
# [0]	train-map@3:0.30810	eval-map@3:0.29456
# [100]	train-map@3:0.35377	eval-map@3:0.32490
# [200]	train-map@3:0.36467	eval-map@3:0.32994
# [300]	train-map@3:0.37472	eval-map@3:0.33367
# [400]	train-map@3:0.38402	eval-map@3:0.33720
# [500]	train-map@3:0.39337	eval-map@3:0.34086
# [600]	train-map@3:0.40196	eval-map@3:0.34356
# [700]	train-map@3:0.41049	eval-map@3:0.34635
# [800]	train-map@3:0.41791	eval-map@3:0.34876
# [900]	train-map@3:0.42530	eval-map@3:0.35103
# [1000]	train-map@3:0.43206	eval-map@3:0.35277
# [1100]	train-map@3:0.43843	eval-map@3:0.35469
# [1200]	train-map@3:0.44428	eval-map@3:0.35642
# [1300]	train-map@3:0.44984	eval-map@3:0.35773
# [1400]	train-map@3:0.45473	eval-map@3:0.35898
# [1500]	train-map@3:0.45937	eval-map@3:0.35999
# [1600]	train-map@3:0.46375	eval-map@3:0.36090
# [1700]	train-map@3:0.46764	eval-map@3:0.36175
# [1800]	train-map@3:0.47123	eval-map@3:0.36253
# [1900]	train-map@3:0.47479	eval-map@3:0.36300
# [2000]	train-map@3:0.47778	eval-map@3:0.36353
# [2100]	train-map@3:0.48102	eval-map@3:0.36415
# [2200]	train-map@3:0.48406	eval-map@3:0.36446
# [2300]	train-map@3:0.48668	eval-map@3:0.36494
# [2400]	train-map@3:0.48901	eval-map@3:0.36537
# [2500]	train-map@3:0.49164	eval-map@3:0.36566
# [2600]	train-map@3:0.49384	eval-map@3:0.36614
# [2700]	train-map@3:0.49598	eval-map@3:0.36636
# [2800]	train-map@3:0.49807	eval-map@3:0.36678
# [2900]	train-map@3:0.50027	eval-map@3:0.36696
# [3000]	train-map@3:0.50242	eval-map@3:0.36706
# [3100]	train-map@3:0.50427	eval-map@3:0.36718
# [3200]	train-map@3:0.50587	eval-map@3:0.36749
# [3300]	train-map@3:0.50776	eval-map@3:0.36762
# [3400]	train-map@3:0.50942	eval-map@3:0.36779
# [3500]	train-map@3:0.51110	eval-map@3:0.36780
# [3600]	train-map@3:0.51264	eval-map@3:0.36789
# [3700]	train-map@3:0.51423	eval-map@3:0.36800
# [3800]	train-map@3:0.51562	eval-map@3:0.36819
# [3900]	train-map@3:0.51697	eval-map@3:0.36808
# [3938]	train-map@3:0.51748	eval-map@3:0.36812
# Training time: 01:03:05
# Train map@3: 0.51613
# Valid map@3: 0.36832
#
# Fold 3
# [0]	train-map@3:0.30831	eval-map@3:0.29737
# [100]	train-map@3:0.35413	eval-map@3:0.32500
# [200]	train-map@3:0.36524	eval-map@3:0.33034
# [300]	train-map@3:0.37489	eval-map@3:0.33462
# [400]	train-map@3:0.38424	eval-map@3:0.33815
# [500]	train-map@3:0.39335	eval-map@3:0.34140
# [600]	train-map@3:0.40184	eval-map@3:0.34392
# [700]	train-map@3:0.41035	eval-map@3:0.34668
# [800]	train-map@3:0.41801	eval-map@3:0.34917
# [900]	train-map@3:0.42544	eval-map@3:0.35130
# [1000]	train-map@3:0.43218	eval-map@3:0.35344
# [1100]	train-map@3:0.43851	eval-map@3:0.35497
# [1200]	train-map@3:0.44439	eval-map@3:0.35667
# [1300]	train-map@3:0.44986	eval-map@3:0.35825
# [1400]	train-map@3:0.45464	eval-map@3:0.35933
# [1500]	train-map@3:0.45921	eval-map@3:0.36053
# [1600]	train-map@3:0.46355	eval-map@3:0.36145
# [1700]	train-map@3:0.46735	eval-map@3:0.36237
# [1800]	train-map@3:0.47093	eval-map@3:0.36302
# [1900]	train-map@3:0.47460	eval-map@3:0.36352
# [2000]	train-map@3:0.47774	eval-map@3:0.36431
# [2100]	train-map@3:0.48086	eval-map@3:0.36474
# [2200]	train-map@3:0.48393	eval-map@3:0.36540
# [2300]	train-map@3:0.48644	eval-map@3:0.36591
# [2400]	train-map@3:0.48886	eval-map@3:0.36616
# [2500]	train-map@3:0.49140	eval-map@3:0.36624
# [2600]	train-map@3:0.49373	eval-map@3:0.36663
# [2700]	train-map@3:0.49596	eval-map@3:0.36696
# [2800]	train-map@3:0.49791	eval-map@3:0.36713
# [2900]	train-map@3:0.50016	eval-map@3:0.36729
# [2948]	train-map@3:0.50118	eval-map@3:0.36715
# Training time: 00:47:03
# Train map@3: 0.49896
# Valid map@3: 0.36733
#
# Fold 4
# [0]	train-map@3:0.30858	eval-map@3:0.29460
# [100]	train-map@3:0.35392	eval-map@3:0.32421
# [200]	train-map@3:0.36497	eval-map@3:0.32943
# [300]	train-map@3:0.37493	eval-map@3:0.33346
# [400]	train-map@3:0.38418	eval-map@3:0.33705
# [500]	train-map@3:0.39345	eval-map@3:0.34074
# [600]	train-map@3:0.40193	eval-map@3:0.34336
# [700]	train-map@3:0.41031	eval-map@3:0.34578
# [800]	train-map@3:0.41794	eval-map@3:0.34835
# [900]	train-map@3:0.42542	eval-map@3:0.35064
# [1000]	train-map@3:0.43207	eval-map@3:0.35273
# [1100]	train-map@3:0.43840	eval-map@3:0.35479
# [1200]	train-map@3:0.44438	eval-map@3:0.35613
# [1300]	train-map@3:0.44982	eval-map@3:0.35763
# [1400]	train-map@3:0.45462	eval-map@3:0.35868
# [1500]	train-map@3:0.45922	eval-map@3:0.35983
# [1600]	train-map@3:0.46350	eval-map@3:0.36059
# [1700]	train-map@3:0.46751	eval-map@3:0.36151
# [1800]	train-map@3:0.47109	eval-map@3:0.36225
# [1900]	train-map@3:0.47454	eval-map@3:0.36292
# [2000]	train-map@3:0.47765	eval-map@3:0.36312
# [2100]	train-map@3:0.48073	eval-map@3:0.36361
# [2200]	train-map@3:0.48383	eval-map@3:0.36428
# [2300]	train-map@3:0.48643	eval-map@3:0.36478
# [2400]	train-map@3:0.48894	eval-map@3:0.36505
# [2500]	train-map@3:0.49150	eval-map@3:0.36536
# [2600]	train-map@3:0.49384	eval-map@3:0.36541
# [2700]	train-map@3:0.49594	eval-map@3:0.36549
# [2800]	train-map@3:0.49801	eval-map@3:0.36588
# [2900]	train-map@3:0.50022	eval-map@3:0.36590
# [2940]	train-map@3:0.50108	eval-map@3:0.36591
# Training time: 00:47:44
# Train map@3: 0.49894
# Valid map@3: 0.36600
#
# Fold 5
# [0]	train-map@3:0.30830	eval-map@3:0.29560
# [100]	train-map@3:0.35410	eval-map@3:0.32481
# [200]	train-map@3:0.36519	eval-map@3:0.32992
# [300]	train-map@3:0.37498	eval-map@3:0.33411
# [400]	train-map@3:0.38449	eval-map@3:0.33717
# [500]	train-map@3:0.39373	eval-map@3:0.34059
# [600]	train-map@3:0.40231	eval-map@3:0.34346
# [700]	train-map@3:0.41097	eval-map@3:0.34585
# [800]	train-map@3:0.41844	eval-map@3:0.34835
# [900]	train-map@3:0.42580	eval-map@3:0.35051
# [1000]	train-map@3:0.43248	eval-map@3:0.35252
# [1100]	train-map@3:0.43865	eval-map@3:0.35415
# [1200]	train-map@3:0.44458	eval-map@3:0.35564
# [1300]	train-map@3:0.44988	eval-map@3:0.35731
# [1400]	train-map@3:0.45480	eval-map@3:0.35833
# [1500]	train-map@3:0.45927	eval-map@3:0.35925
# [1600]	train-map@3:0.46356	eval-map@3:0.36004
# [1700]	train-map@3:0.46762	eval-map@3:0.36101
# [1800]	train-map@3:0.47125	eval-map@3:0.36160
# [1900]	train-map@3:0.47486	eval-map@3:0.36224
# [2000]	train-map@3:0.47788	eval-map@3:0.36255
# [2100]	train-map@3:0.48102	eval-map@3:0.36339
# [2200]	train-map@3:0.48398	eval-map@3:0.36382
# [2300]	train-map@3:0.48654	eval-map@3:0.36421
# [2400]	train-map@3:0.48899	eval-map@3:0.36461
# [2500]	train-map@3:0.49152	eval-map@3:0.36481
# [2600]	train-map@3:0.49388	eval-map@3:0.36512
# [2700]	train-map@3:0.49596	eval-map@3:0.36515
# [2800]	train-map@3:0.49803	eval-map@3:0.36529
# [2900]	train-map@3:0.50028	eval-map@3:0.36535
# [3000]	train-map@3:0.50228	eval-map@3:0.36566
# [3100]	train-map@3:0.50414	eval-map@3:0.36585
# [3200]	train-map@3:0.50596	eval-map@3:0.36583
# [3210]	train-map@3:0.50611	eval-map@3:0.36582
# Training time: 00:52:29
# Train map@3: 0.50439
# Valid map@3: 0.36602
#
# === CV 結果 ===
# Fold scores: [0.36853, 0.368324, 0.367326, 0.366, 0.366016]
# Mean: 0.36724, Std: 0.00108
# OOF score: 0.36707
