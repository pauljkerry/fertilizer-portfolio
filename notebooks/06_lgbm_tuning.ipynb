# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import optuna

sys.path.append(os.path.abspath(".."))

import src.models.lgbm.lgbm_cv_trainer as cv
import src.models.lgbm.lgbm_optuna_optimizer as op

# %%
# データの読み込み
env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=env_path)
url = os.environ.get("OPTUNA_STORAGE_URL")

tr_df4 = pd.read_csv("../artifacts/features/tr_df4.csv")
test_df4 = pd.read_csv("../artifacts/features/test_df4.csv")

cat_cols = [
    "Tem", "Hum", "Moi", "N", "K", "P", "Soil", "Crop"
]

# %%
# tr_df4のtuning
objective = op.create_objective(
    tr_df4,
    early_stopping_rounds=100,
    cat_cols=cat_cols,
    n_jobs=25
)

random_sampler = optuna.samplers.RandomSampler(seed=42)

study = op.run_optuna_search(
    objective,
    n_trials=30,
    n_jobs=1,
    study_name="lgb_v4",
    storage=url,
    # initial_params=params
)
# Out:
# [I 2025-07-09 17:57:01,864] Using an existing study with name 'lgb_v4' instead of creating a new one.
#   0%|          | 0/30 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.92115	train's map@3: 0.329293	eval's multi_logloss: 1.92748	eval's map@3: 0.318653
# [200]	train's multi_logloss: 1.91989	train's map@3: 0.3296	eval's multi_logloss: 1.92693	eval's map@3: 0.319139
# Early stopping, best iteration is:
# [187]	train's multi_logloss: 1.91994	train's map@3: 0.329685	eval's multi_logloss: 1.92693	eval's map@3: 0.319275
# Training time: 00:03:25
# Train map@3: 0.32969
# Valid map@3: 0.31927
# [I 2025-07-09 18:00:27,498] Trial 3 finished with value: 0.3192745098039216 and parameters: {'max_depth': 7, 'num_leaves': 525, 'min_child_samples': 5692, 'min_split_gain': 1.7962148524739476, 'feature_fraction': 0.2648088714001867, 'bagging_fraction': 0.9244412457992262, 'bagging_freq': 10, 'lambda_l1': 2.43976509540032, 'lambda_l2': 0.10367666255746932}. Best is trial 3 with value: 0.3192745098039216.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90313	train's map@3: 0.357629	eval's multi_logloss: 1.92034	eval's map@3: 0.330003
# [200]	train's multi_logloss: 1.88092	train's map@3: 0.38849	eval's multi_logloss: 1.91204	eval's map@3: 0.342118
# [300]	train's multi_logloss: 1.86275	train's map@3: 0.408787	eval's multi_logloss: 1.90608	eval's map@3: 0.349028
# [400]	train's multi_logloss: 1.84684	train's map@3: 0.423768	eval's multi_logloss: 1.90178	eval's map@3: 0.35383
# [500]	train's multi_logloss: 1.83301	train's map@3: 0.434899	eval's multi_logloss: 1.89886	eval's map@3: 0.356885
# [600]	train's multi_logloss: 1.82095	train's map@3: 0.443318	eval's multi_logloss: 1.89687	eval's map@3: 0.358774
# [700]	train's multi_logloss: 1.81011	train's map@3: 0.450061	eval's multi_logloss: 1.89575	eval's map@3: 0.360377
# [800]	train's multi_logloss: 1.80002	train's map@3: 0.456052	eval's multi_logloss: 1.89509	eval's map@3: 0.360733
# [900]	train's multi_logloss: 1.79071	train's map@3: 0.461414	eval's multi_logloss: 1.89495	eval's map@3: 0.361601
# [1000]	train's multi_logloss: 1.78271	train's map@3: 0.465638	eval's multi_logloss: 1.89507	eval's map@3: 0.362147
# Early stopping, best iteration is:
# [938]	train's multi_logloss: 1.78761	train's map@3: 0.463113	eval's multi_logloss: 1.89489	eval's map@3: 0.362007
# Training time: 00:13:16
# Train map@3: 0.46311
# Valid map@3: 0.36201
# [I 2025-07-09 18:13:44,921] Trial 4 finished with value: 0.3620068627450981 and parameters: {'max_depth': 7, 'num_leaves': 536, 'min_child_samples': 11204, 'min_split_gain': 0.036930341371084904, 'feature_fraction': 0.38458350086037285, 'bagging_fraction': 0.6671215249541288, 'bagging_freq': 6, 'lambda_l1': 0.03493927174274212, 'lambda_l2': 1.3096995862575729e-05}. Best is trial 4 with value: 0.3620068627450981.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90305	train's map@3: 0.358152	eval's multi_logloss: 1.92008	eval's map@3: 0.331101
# [200]	train's multi_logloss: 1.88107	train's map@3: 0.388415	eval's multi_logloss: 1.91146	eval's map@3: 0.342846
# [300]	train's multi_logloss: 1.86283	train's map@3: 0.409126	eval's multi_logloss: 1.90543	eval's map@3: 0.35043
# [400]	train's multi_logloss: 1.84682	train's map@3: 0.42404	eval's multi_logloss: 1.90118	eval's map@3: 0.354684
# [500]	train's multi_logloss: 1.83289	train's map@3: 0.435227	eval's multi_logloss: 1.8983	eval's map@3: 0.357562
# [600]	train's multi_logloss: 1.8208	train's map@3: 0.444003	eval's multi_logloss: 1.89617	eval's map@3: 0.359352
# [700]	train's multi_logloss: 1.81	train's map@3: 0.450843	eval's multi_logloss: 1.8949	eval's map@3: 0.361005
# [800]	train's multi_logloss: 1.7999	train's map@3: 0.456828	eval's multi_logloss: 1.89434	eval's map@3: 0.361615
# [900]	train's multi_logloss: 1.79069	train's map@3: 0.46196	eval's multi_logloss: 1.894	eval's map@3: 0.362623
# [1000]	train's multi_logloss: 1.78282	train's map@3: 0.466137	eval's multi_logloss: 1.89419	eval's map@3: 0.362778
# Early stopping, best iteration is:
# [910]	train's multi_logloss: 1.78984	train's map@3: 0.46239	eval's multi_logloss: 1.89395	eval's map@3: 0.362986
# Training time: 00:12:48
# Train map@3: 0.46239
# Valid map@3: 0.36299
# [I 2025-07-09 18:26:34,381] Trial 5 finished with value: 0.362986274509804 and parameters: {'max_depth': 8, 'num_leaves': 526, 'min_child_samples': 11991, 'min_split_gain': 0.015554228112067093, 'feature_fraction': 0.35724834384303783, 'bagging_fraction': 0.7065871108921251, 'bagging_freq': 4, 'lambda_l1': 0.0004093204682439238, 'lambda_l2': 0.04996952215255948}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.91486	train's map@3: 0.340673	eval's multi_logloss: 1.9242	eval's map@3: 0.324348
# [200]	train's multi_logloss: 1.90412	train's map@3: 0.355205	eval's multi_logloss: 1.91914	eval's map@3: 0.331712
# [300]	train's multi_logloss: 1.89575	train's map@3: 0.366149	eval's multi_logloss: 1.9157	eval's map@3: 0.336175
# [400]	train's multi_logloss: 1.88893	train's map@3: 0.374386	eval's multi_logloss: 1.91302	eval's map@3: 0.340287
# [500]	train's multi_logloss: 1.88287	train's map@3: 0.380712	eval's multi_logloss: 1.91093	eval's map@3: 0.342287
# [600]	train's multi_logloss: 1.87782	train's map@3: 0.385556	eval's multi_logloss: 1.90939	eval's map@3: 0.344359
# [700]	train's multi_logloss: 1.87332	train's map@3: 0.389618	eval's multi_logloss: 1.90822	eval's map@3: 0.345677
# [800]	train's multi_logloss: 1.86961	train's map@3: 0.392638	eval's multi_logloss: 1.90725	eval's map@3: 0.34679
# [900]	train's multi_logloss: 1.86604	train's map@3: 0.395132	eval's multi_logloss: 1.9065	eval's map@3: 0.347718
# [1000]	train's multi_logloss: 1.86327	train's map@3: 0.396909	eval's multi_logloss: 1.90612	eval's map@3: 0.348217
# [1100]	train's multi_logloss: 1.8605	train's map@3: 0.398802	eval's multi_logloss: 1.9059	eval's map@3: 0.348644
# [1200]	train's multi_logloss: 1.85814	train's map@3: 0.400428	eval's multi_logloss: 1.90581	eval's map@3: 0.348979
# [1300]	train's multi_logloss: 1.85612	train's map@3: 0.401447	eval's multi_logloss: 1.9057	eval's map@3: 0.349471
# Early stopping, best iteration is:
# [1242]	train's multi_logloss: 1.85725	train's map@3: 0.400662	eval's multi_logloss: 1.90566	eval's map@3: 0.349547
# Training time: 00:16:37
# Train map@3: 0.40066
# Valid map@3: 0.34955
# [I 2025-07-09 18:43:12,711] Trial 6 finished with value: 0.34954705882352943 and parameters: {'max_depth': 7, 'num_leaves': 523, 'min_child_samples': 9479, 'min_split_gain': 0.282696672451169, 'feature_fraction': 0.2634078879472024, 'bagging_fraction': 0.7790437241192477, 'bagging_freq': 14, 'lambda_l1': 8.448806852524251e-05, 'lambda_l2': 0.3600048137148016}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.8989	train's map@3: 0.364497	eval's multi_logloss: 1.91953	eval's map@3: 0.33085
# [200]	train's multi_logloss: 1.88886	train's map@3: 0.378731	eval's multi_logloss: 1.916	eval's map@3: 0.335658
# [300]	train's multi_logloss: 1.88141	train's map@3: 0.38864	eval's multi_logloss: 1.9136	eval's map@3: 0.339136
# [400]	train's multi_logloss: 1.87313	train's map@3: 0.399265	eval's multi_logloss: 1.91102	eval's map@3: 0.341951
# [500]	train's multi_logloss: 1.86544	train's map@3: 0.407673	eval's multi_logloss: 1.90872	eval's map@3: 0.345064
# [600]	train's multi_logloss: 1.85906	train's map@3: 0.414625	eval's multi_logloss: 1.90706	eval's map@3: 0.34756
# [700]	train's multi_logloss: 1.85282	train's map@3: 0.420804	eval's multi_logloss: 1.90563	eval's map@3: 0.348911
# [800]	train's multi_logloss: 1.84684	train's map@3: 0.426151	eval's multi_logloss: 1.90423	eval's map@3: 0.350456
# [900]	train's multi_logloss: 1.84185	train's map@3: 0.430259	eval's multi_logloss: 1.90326	eval's map@3: 0.351681
# [1000]	train's multi_logloss: 1.83706	train's map@3: 0.434225	eval's multi_logloss: 1.90237	eval's map@3: 0.352438
# [1100]	train's multi_logloss: 1.83205	train's map@3: 0.4379	eval's multi_logloss: 1.90152	eval's map@3: 0.353252
# [1200]	train's multi_logloss: 1.82682	train's map@3: 0.44192	eval's multi_logloss: 1.90055	eval's map@3: 0.354126
# [1300]	train's multi_logloss: 1.82309	train's map@3: 0.444324	eval's multi_logloss: 1.89999	eval's map@3: 0.35482
# [1400]	train's multi_logloss: 1.81965	train's map@3: 0.446343	eval's multi_logloss: 1.8996	eval's map@3: 0.355046
# [1500]	train's multi_logloss: 1.81644	train's map@3: 0.448574	eval's multi_logloss: 1.89936	eval's map@3: 0.355621
# [1600]	train's multi_logloss: 1.81241	train's map@3: 0.451155	eval's multi_logloss: 1.89898	eval's map@3: 0.355829
# [1700]	train's multi_logloss: 1.80852	train's map@3: 0.453233	eval's multi_logloss: 1.89865	eval's map@3: 0.356349
# [1800]	train's multi_logloss: 1.80556	train's map@3: 0.454995	eval's multi_logloss: 1.89861	eval's map@3: 0.356477
# Early stopping, best iteration is:
# [1703]	train's multi_logloss: 1.80846	train's map@3: 0.453318	eval's multi_logloss: 1.89865	eval's map@3: 0.356536
# Training time: 00:21:46
# Train map@3: 0.45332
# Valid map@3: 0.35654
# [I 2025-07-09 19:04:59,914] Trial 7 finished with value: 0.35653627450980396 and parameters: {'max_depth': 7, 'num_leaves': 597, 'min_child_samples': 8269, 'min_split_gain': 0.8538484402650572, 'feature_fraction': 0.4198451809273763, 'bagging_fraction': 0.8486687916472575, 'bagging_freq': 15, 'lambda_l1': 0.8388258295562702, 'lambda_l2': 0.0005003606250203778}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.91247	train's map@3: 0.34472	eval's multi_logloss: 1.92318	eval's map@3: 0.326271
# [200]	train's multi_logloss: 1.89938	train's map@3: 0.361419	eval's multi_logloss: 1.91718	eval's map@3: 0.334204
# [300]	train's multi_logloss: 1.88921	train's map@3: 0.373519	eval's multi_logloss: 1.913	eval's map@3: 0.338881
# [400]	train's multi_logloss: 1.88139	train's map@3: 0.380842	eval's multi_logloss: 1.9103	eval's map@3: 0.342388
# [500]	train's multi_logloss: 1.87458	train's map@3: 0.387121	eval's multi_logloss: 1.90838	eval's map@3: 0.344707
# [600]	train's multi_logloss: 1.86919	train's map@3: 0.391372	eval's multi_logloss: 1.90735	eval's map@3: 0.346246
# [700]	train's multi_logloss: 1.86472	train's map@3: 0.394744	eval's multi_logloss: 1.90676	eval's map@3: 0.346978
# [800]	train's multi_logloss: 1.86123	train's map@3: 0.397054	eval's multi_logloss: 1.90657	eval's map@3: 0.348002
# [900]	train's multi_logloss: 1.85789	train's map@3: 0.399189	eval's multi_logloss: 1.9064	eval's map@3: 0.348049
# Early stopping, best iteration is:
# [891]	train's multi_logloss: 1.85817	train's map@3: 0.399002	eval's multi_logloss: 1.90636	eval's map@3: 0.348216
# Training time: 00:12:48
# Train map@3: 0.39900
# Valid map@3: 0.34822
# [I 2025-07-09 19:17:48,861] Trial 8 finished with value: 0.3482156862745098 and parameters: {'max_depth': 8, 'num_leaves': 705, 'min_child_samples': 5437, 'min_split_gain': 0.019718127023936362, 'feature_fraction': 0.30405348814834465, 'bagging_fraction': 0.6533772736165192, 'bagging_freq': 13, 'lambda_l1': 4.246530214511101, 'lambda_l2': 8.137435826681015e-05}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.91217	train's map@3: 0.345526	eval's multi_logloss: 1.92295	eval's map@3: 0.3267
# [200]	train's multi_logloss: 1.89927	train's map@3: 0.361944	eval's multi_logloss: 1.91697	eval's map@3: 0.334794
# [300]	train's multi_logloss: 1.88924	train's map@3: 0.374092	eval's multi_logloss: 1.91279	eval's map@3: 0.340102
# [400]	train's multi_logloss: 1.8816	train's map@3: 0.382143	eval's multi_logloss: 1.91003	eval's map@3: 0.343438
# [500]	train's multi_logloss: 1.87494	train's map@3: 0.388386	eval's multi_logloss: 1.90803	eval's map@3: 0.345469
# [600]	train's multi_logloss: 1.86961	train's map@3: 0.392719	eval's multi_logloss: 1.90672	eval's map@3: 0.34702
# [700]	train's multi_logloss: 1.86532	train's map@3: 0.396001	eval's multi_logloss: 1.90582	eval's map@3: 0.348258
# [800]	train's multi_logloss: 1.86188	train's map@3: 0.398463	eval's multi_logloss: 1.90537	eval's map@3: 0.348636
# [900]	train's multi_logloss: 1.85852	train's map@3: 0.400375	eval's multi_logloss: 1.90506	eval's map@3: 0.349439
# [1000]	train's multi_logloss: 1.85611	train's map@3: 0.401729	eval's multi_logloss: 1.90503	eval's map@3: 0.349625
# Early stopping, best iteration is:
# [957]	train's multi_logloss: 1.85716	train's map@3: 0.401258	eval's multi_logloss: 1.90502	eval's map@3: 0.349585
# Training time: 00:13:44
# Train map@3: 0.40126
# Valid map@3: 0.34959
# [I 2025-07-09 19:31:33,813] Trial 9 finished with value: 0.34958529411764705 and parameters: {'max_depth': 8, 'num_leaves': 546, 'min_child_samples': 7414, 'min_split_gain': 0.026830351552985597, 'feature_fraction': 0.2832295663015193, 'bagging_fraction': 0.94966024698366, 'bagging_freq': 7, 'lambda_l1': 5.8511373417197685, 'lambda_l2': 1.6723149983175794e-05}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.91316	train's map@3: 0.34336	eval's multi_logloss: 1.92327	eval's map@3: 0.326632
# [200]	train's multi_logloss: 1.90058	train's map@3: 0.359454	eval's multi_logloss: 1.9175	eval's map@3: 0.332833
# [300]	train's multi_logloss: 1.89069	train's map@3: 0.370872	eval's multi_logloss: 1.91353	eval's map@3: 0.338601
# [400]	train's multi_logloss: 1.88305	train's map@3: 0.378959	eval's multi_logloss: 1.91079	eval's map@3: 0.341899
# [500]	train's multi_logloss: 1.87639	train's map@3: 0.385245	eval's multi_logloss: 1.90887	eval's map@3: 0.344073
# [600]	train's multi_logloss: 1.87098	train's map@3: 0.38961	eval's multi_logloss: 1.90775	eval's map@3: 0.345418
# [700]	train's multi_logloss: 1.86656	train's map@3: 0.392831	eval's multi_logloss: 1.90696	eval's map@3: 0.346736
# [800]	train's multi_logloss: 1.86296	train's map@3: 0.395401	eval's multi_logloss: 1.9067	eval's map@3: 0.346853
# [900]	train's multi_logloss: 1.85955	train's map@3: 0.397484	eval's multi_logloss: 1.90661	eval's map@3: 0.347824
# [1000]	train's multi_logloss: 1.857	train's map@3: 0.39919	eval's multi_logloss: 1.90662	eval's map@3: 0.347789
# Early stopping, best iteration is:
# [960]	train's multi_logloss: 1.85803	train's map@3: 0.398511	eval's multi_logloss: 1.90659	eval's map@3: 0.347994
# Training time: 00:13:55
# Train map@3: 0.39851
# Valid map@3: 0.34799
# [I 2025-07-09 19:45:29,828] Trial 10 finished with value: 0.34799411764705873 and parameters: {'max_depth': 7, 'num_leaves': 585, 'min_child_samples': 8608, 'min_split_gain': 0.0018889515878681663, 'feature_fraction': 0.2632804265818506, 'bagging_fraction': 0.7045413418747389, 'bagging_freq': 3, 'lambda_l1': 0.00015445200118903503, 'lambda_l2': 4.22470908047563}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90571	train's map@3: 0.354076	eval's multi_logloss: 1.92112	eval's map@3: 0.329218
# [200]	train's multi_logloss: 1.8854	train's map@3: 0.382939	eval's multi_logloss: 1.91293	eval's map@3: 0.341
# [300]	train's multi_logloss: 1.86865	train's map@3: 0.403044	eval's multi_logloss: 1.90706	eval's map@3: 0.348249
# [400]	train's multi_logloss: 1.85373	train's map@3: 0.418473	eval's multi_logloss: 1.90244	eval's map@3: 0.353074
# [500]	train's multi_logloss: 1.84089	train's map@3: 0.429102	eval's multi_logloss: 1.89925	eval's map@3: 0.356326
# [600]	train's multi_logloss: 1.82955	train's map@3: 0.437223	eval's multi_logloss: 1.89711	eval's map@3: 0.358436
# [700]	train's multi_logloss: 1.81937	train's map@3: 0.444138	eval's multi_logloss: 1.89571	eval's map@3: 0.35959
# [800]	train's multi_logloss: 1.80994	train's map@3: 0.450011	eval's multi_logloss: 1.89469	eval's map@3: 0.361084
# [900]	train's multi_logloss: 1.80118	train's map@3: 0.455059	eval's multi_logloss: 1.89396	eval's map@3: 0.362117
# [1000]	train's multi_logloss: 1.79373	train's map@3: 0.459258	eval's multi_logloss: 1.89378	eval's map@3: 0.36277
# [1100]	train's multi_logloss: 1.78667	train's map@3: 0.463205	eval's multi_logloss: 1.89385	eval's map@3: 0.363289
# Early stopping, best iteration is:
# [1007]	train's multi_logloss: 1.79316	train's map@3: 0.459608	eval's multi_logloss: 1.89375	eval's map@3: 0.36274
# Training time: 00:13:37
# Train map@3: 0.45961
# Valid map@3: 0.36274
# [I 2025-07-09 19:59:07,985] Trial 11 finished with value: 0.3627401960784314 and parameters: {'max_depth': 8, 'num_leaves': 783, 'min_child_samples': 14687, 'min_split_gain': 1.6360662359683227e-05, 'feature_fraction': 0.33822071846223334, 'bagging_fraction': 0.7500595088909203, 'bagging_freq': 1, 'lambda_l1': 1.0566344926460304e-05, 'lambda_l2': 0.009338770130774393}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90626	train's map@3: 0.353085	eval's multi_logloss: 1.92117	eval's map@3: 0.329725
# [200]	train's multi_logloss: 1.88641	train's map@3: 0.381657	eval's multi_logloss: 1.91325	eval's map@3: 0.340564
# [300]	train's multi_logloss: 1.86989	train's map@3: 0.401649	eval's multi_logloss: 1.9073	eval's map@3: 0.348623
# [400]	train's multi_logloss: 1.85523	train's map@3: 0.41681	eval's multi_logloss: 1.90281	eval's map@3: 0.353396
# [500]	train's multi_logloss: 1.84251	train's map@3: 0.427838	eval's multi_logloss: 1.89968	eval's map@3: 0.356139
# [600]	train's multi_logloss: 1.8313	train's map@3: 0.436171	eval's multi_logloss: 1.8974	eval's map@3: 0.358725
# [700]	train's multi_logloss: 1.82124	train's map@3: 0.442842	eval's multi_logloss: 1.89578	eval's map@3: 0.359925
# [800]	train's multi_logloss: 1.81192	train's map@3: 0.448768	eval's multi_logloss: 1.89475	eval's map@3: 0.360922
# [900]	train's multi_logloss: 1.80322	train's map@3: 0.454162	eval's multi_logloss: 1.89423	eval's map@3: 0.361845
# [1000]	train's multi_logloss: 1.79578	train's map@3: 0.458056	eval's multi_logloss: 1.89399	eval's map@3: 0.362381
# [1100]	train's multi_logloss: 1.78882	train's map@3: 0.46184	eval's multi_logloss: 1.89419	eval's map@3: 0.362696
# Early stopping, best iteration is:
# [1010]	train's multi_logloss: 1.79503	train's map@3: 0.458508	eval's multi_logloss: 1.89398	eval's map@3: 0.362316
# Training time: 00:13:38
# Train map@3: 0.45851
# Valid map@3: 0.36232
# [I 2025-07-09 20:12:47,145] Trial 12 finished with value: 0.3623156862745098 and parameters: {'max_depth': 8, 'num_leaves': 786, 'min_child_samples': 14932, 'min_split_gain': 1.2981951069910664e-05, 'feature_fraction': 0.3408226994037134, 'bagging_fraction': 0.744523759938435, 'bagging_freq': 1, 'lambda_l1': 1.7342405157267325e-05, 'lambda_l2': 0.007926530768192558}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90609	train's map@3: 0.353259	eval's multi_logloss: 1.92114	eval's map@3: 0.32941
# [200]	train's multi_logloss: 1.88632	train's map@3: 0.381398	eval's multi_logloss: 1.91315	eval's map@3: 0.340885
# [300]	train's multi_logloss: 1.86997	train's map@3: 0.401122	eval's multi_logloss: 1.90732	eval's map@3: 0.347866
# [400]	train's multi_logloss: 1.85541	train's map@3: 0.415943	eval's multi_logloss: 1.90279	eval's map@3: 0.352915
# [500]	train's multi_logloss: 1.84277	train's map@3: 0.426734	eval's multi_logloss: 1.89968	eval's map@3: 0.356543
# [600]	train's multi_logloss: 1.83157	train's map@3: 0.435499	eval's multi_logloss: 1.89745	eval's map@3: 0.358424
# [700]	train's multi_logloss: 1.82163	train's map@3: 0.441982	eval's multi_logloss: 1.89585	eval's map@3: 0.359771
# [800]	train's multi_logloss: 1.81222	train's map@3: 0.447977	eval's multi_logloss: 1.89478	eval's map@3: 0.361092
# [900]	train's multi_logloss: 1.80363	train's map@3: 0.452968	eval's multi_logloss: 1.89401	eval's map@3: 0.362162
# [1000]	train's multi_logloss: 1.79624	train's map@3: 0.457048	eval's multi_logloss: 1.89374	eval's map@3: 0.362678
# [1100]	train's multi_logloss: 1.78931	train's map@3: 0.460591	eval's multi_logloss: 1.89369	eval's map@3: 0.362686
# [1200]	train's multi_logloss: 1.78241	train's map@3: 0.464639	eval's multi_logloss: 1.89394	eval's map@3: 0.363072
# Early stopping, best iteration is:
# [1101]	train's multi_logloss: 1.78925	train's map@3: 0.460648	eval's multi_logloss: 1.89368	eval's map@3: 0.362737
# Training time: 00:14:46
# Train map@3: 0.46065
# Valid map@3: 0.36274
# [I 2025-07-09 20:27:34,156] Trial 13 finished with value: 0.36273725490196074 and parameters: {'max_depth': 8, 'num_leaves': 797, 'min_child_samples': 14573, 'min_split_gain': 1.178245215122182e-05, 'feature_fraction': 0.342360856217114, 'bagging_fraction': 0.7229945707995308, 'bagging_freq': 1, 'lambda_l1': 0.0033859757665156386, 'lambda_l2': 0.008148178643631696}. Best is trial 5 with value: 0.362986274509804.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90277	train's map@3: 0.358404	eval's multi_logloss: 1.91993	eval's map@3: 0.331006
# [200]	train's multi_logloss: 1.88046	train's map@3: 0.389495	eval's multi_logloss: 1.91139	eval's map@3: 0.343309
# [300]	train's multi_logloss: 1.86196	train's map@3: 0.410692	eval's multi_logloss: 1.90528	eval's map@3: 0.349908
# [400]	train's multi_logloss: 1.84584	train's map@3: 0.425709	eval's multi_logloss: 1.90094	eval's map@3: 0.354899
# [500]	train's multi_logloss: 1.83177	train's map@3: 0.437069	eval's multi_logloss: 1.89782	eval's map@3: 0.357737
# [600]	train's multi_logloss: 1.8195	train's map@3: 0.445696	eval's multi_logloss: 1.89573	eval's map@3: 0.359909
# [700]	train's multi_logloss: 1.80858	train's map@3: 0.452342	eval's multi_logloss: 1.89429	eval's map@3: 0.3611
# [800]	train's multi_logloss: 1.79836	train's map@3: 0.458536	eval's multi_logloss: 1.89347	eval's map@3: 0.362782
# [900]	train's multi_logloss: 1.78888	train's map@3: 0.463893	eval's multi_logloss: 1.8933	eval's map@3: 0.363611
# Early stopping, best iteration is:
# [881]	train's multi_logloss: 1.79065	train's map@3: 0.463017	eval's multi_logloss: 1.89323	eval's map@3: 0.363635
# Training time: 00:12:36
# Train map@3: 0.46302
# Valid map@3: 0.36364
# [I 2025-07-09 20:40:11,331] Trial 14 finished with value: 0.36363529411764706 and parameters: {'max_depth': 8, 'num_leaves': 739, 'min_child_samples': 13115, 'min_split_gain': 0.0002438950133036178, 'feature_fraction': 0.3783334991840541, 'bagging_fraction': 0.7837039549253348, 'bagging_freq': 4, 'lambda_l1': 0.002694659698477768, 'lambda_l2': 0.06610324447471909}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90193	train's map@3: 0.35963	eval's multi_logloss: 1.9196	eval's map@3: 0.331932
# [200]	train's multi_logloss: 1.87916	train's map@3: 0.390715	eval's multi_logloss: 1.91064	eval's map@3: 0.344224
# [300]	train's multi_logloss: 1.86041	train's map@3: 0.412161	eval's multi_logloss: 1.90448	eval's map@3: 0.351847
# [400]	train's multi_logloss: 1.84403	train's map@3: 0.427547	eval's multi_logloss: 1.90015	eval's map@3: 0.356468
# [500]	train's multi_logloss: 1.82963	train's map@3: 0.438754	eval's multi_logloss: 1.89695	eval's map@3: 0.359095
# [600]	train's multi_logloss: 1.81714	train's map@3: 0.447507	eval's multi_logloss: 1.89508	eval's map@3: 0.360971
# [700]	train's multi_logloss: 1.80592	train's map@3: 0.454259	eval's multi_logloss: 1.89382	eval's map@3: 0.362213
# [800]	train's multi_logloss: 1.79552	train's map@3: 0.460472	eval's multi_logloss: 1.89338	eval's map@3: 0.362738
# Early stopping, best iteration is:
# [746]	train's multi_logloss: 1.80095	train's map@3: 0.457269	eval's multi_logloss: 1.89355	eval's map@3: 0.363067
# Training time: 00:10:55
# Train map@3: 0.45727
# Valid map@3: 0.36307
# [I 2025-07-09 20:51:07,575] Trial 15 finished with value: 0.36306666666666665 and parameters: {'max_depth': 8, 'num_leaves': 728, 'min_child_samples': 12789, 'min_split_gain': 0.00016045647513429588, 'feature_fraction': 0.38640241311491713, 'bagging_fraction': 0.7949327887407205, 'bagging_freq': 4, 'lambda_l1': 0.004066159800060059, 'lambda_l2': 0.11276636208762578}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.89617	train's map@3: 0.368071	eval's multi_logloss: 1.91934	eval's map@3: 0.331528
# [200]	train's multi_logloss: 1.86915	train's map@3: 0.403352	eval's multi_logloss: 1.91093	eval's map@3: 0.343289
# [300]	train's multi_logloss: 1.84632	train's map@3: 0.426985	eval's multi_logloss: 1.90575	eval's map@3: 0.348705
# [400]	train's multi_logloss: 1.82673	train's map@3: 0.44419	eval's multi_logloss: 1.90234	eval's map@3: 0.352475
# [500]	train's multi_logloss: 1.80916	train's map@3: 0.457441	eval's multi_logloss: 1.89994	eval's map@3: 0.355158
# [600]	train's multi_logloss: 1.79319	train's map@3: 0.467917	eval's multi_logloss: 1.89867	eval's map@3: 0.356552
# [700]	train's multi_logloss: 1.77882	train's map@3: 0.477306	eval's multi_logloss: 1.89798	eval's map@3: 0.358195
# [800]	train's multi_logloss: 1.76555	train's map@3: 0.485521	eval's multi_logloss: 1.89783	eval's map@3: 0.358592
# Early stopping, best iteration is:
# [783]	train's multi_logloss: 1.76775	train's map@3: 0.484188	eval's multi_logloss: 1.89779	eval's map@3: 0.358747
# Training time: 00:11:26
# Train map@3: 0.48419
# Valid map@3: 0.35875
# [I 2025-07-09 21:02:34,402] Trial 16 finished with value: 0.35874705882352936 and parameters: {'max_depth': 8, 'num_leaves': 728, 'min_child_samples': 13179, 'min_split_gain': 0.00015797891323683348, 'feature_fraction': 0.44680979088429096, 'bagging_fraction': 0.8140009237560856, 'bagging_freq': 10, 'lambda_l1': 0.025055549749439597, 'lambda_l2': 0.9479302217836808}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90285	train's map@3: 0.358584	eval's multi_logloss: 1.91994	eval's map@3: 0.330409
# [200]	train's multi_logloss: 1.88029	train's map@3: 0.389332	eval's multi_logloss: 1.91133	eval's map@3: 0.342824
# [300]	train's multi_logloss: 1.86183	train's map@3: 0.410423	eval's multi_logloss: 1.9052	eval's map@3: 0.350748
# [400]	train's multi_logloss: 1.84578	train's map@3: 0.425808	eval's multi_logloss: 1.90081	eval's map@3: 0.354874
# [500]	train's multi_logloss: 1.83173	train's map@3: 0.436876	eval's multi_logloss: 1.89753	eval's map@3: 0.358161
# [600]	train's multi_logloss: 1.81951	train's map@3: 0.445223	eval's multi_logloss: 1.89571	eval's map@3: 0.359722
# [700]	train's multi_logloss: 1.80858	train's map@3: 0.452088	eval's multi_logloss: 1.89462	eval's map@3: 0.360606
# [800]	train's multi_logloss: 1.79835	train's map@3: 0.45827	eval's multi_logloss: 1.89407	eval's map@3: 0.361684
# [900]	train's multi_logloss: 1.78896	train's map@3: 0.463551	eval's multi_logloss: 1.89376	eval's map@3: 0.362157
# Early stopping, best iteration is:
# [879]	train's multi_logloss: 1.79085	train's map@3: 0.462456	eval's multi_logloss: 1.89374	eval's map@3: 0.362226
# Training time: 00:12:38
# Train map@3: 0.46246
# Valid map@3: 0.36223
# [I 2025-07-09 21:15:13,368] Trial 17 finished with value: 0.36222647058823526 and parameters: {'max_depth': 8, 'num_leaves': 734, 'min_child_samples': 13238, 'min_split_gain': 0.0002095209038990486, 'feature_fraction': 0.3891366913678196, 'bagging_fraction': 0.7920307728591012, 'bagging_freq': 3, 'lambda_l1': 0.003071717638876654, 'lambda_l2': 0.001600047673714013}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.8974	train's map@3: 0.367036	eval's multi_logloss: 1.91817	eval's map@3: 0.333706
# [200]	train's multi_logloss: 1.87116	train's map@3: 0.401306	eval's multi_logloss: 1.90883	eval's map@3: 0.345864
# [300]	train's multi_logloss: 1.84997	train's map@3: 0.422852	eval's multi_logloss: 1.90258	eval's map@3: 0.352895
# [400]	train's multi_logloss: 1.83154	train's map@3: 0.438537	eval's multi_logloss: 1.8983	eval's map@3: 0.357394
# [500]	train's multi_logloss: 1.81556	train's map@3: 0.450013	eval's multi_logloss: 1.89577	eval's map@3: 0.360155
# [600]	train's multi_logloss: 1.80174	train's map@3: 0.458715	eval's multi_logloss: 1.89443	eval's map@3: 0.361075
# [700]	train's multi_logloss: 1.78929	train's map@3: 0.466298	eval's multi_logloss: 1.89369	eval's map@3: 0.362277
# [800]	train's multi_logloss: 1.77761	train's map@3: 0.473016	eval's multi_logloss: 1.89347	eval's map@3: 0.362861
# [900]	train's multi_logloss: 1.76675	train's map@3: 0.478856	eval's multi_logloss: 1.89371	eval's map@3: 0.363302
# Early stopping, best iteration is:
# [820]	train's multi_logloss: 1.77534	train's map@3: 0.47423	eval's multi_logloss: 1.89338	eval's map@3: 0.362978
# Training time: 00:12:08
# Train map@3: 0.47423
# Valid map@3: 0.36298
# [I 2025-07-09 21:27:21,976] Trial 18 finished with value: 0.3629784313725491 and parameters: {'max_depth': 8, 'num_leaves': 692, 'min_child_samples': 10617, 'min_split_gain': 0.00012971468102681538, 'feature_fraction': 0.3883684323714828, 'bagging_fraction': 0.8232425269726212, 'bagging_freq': 5, 'lambda_l1': 0.19004985954961232, 'lambda_l2': 0.06638803912706606}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90327	train's map@3: 0.357787	eval's multi_logloss: 1.91996	eval's map@3: 0.330904
# [200]	train's multi_logloss: 1.88156	train's map@3: 0.388011	eval's multi_logloss: 1.91172	eval's map@3: 0.34277
# [300]	train's multi_logloss: 1.86362	train's map@3: 0.408318	eval's multi_logloss: 1.90568	eval's map@3: 0.3498
# [400]	train's multi_logloss: 1.8478	train's map@3: 0.423713	eval's multi_logloss: 1.90135	eval's map@3: 0.354587
# [500]	train's multi_logloss: 1.8341	train's map@3: 0.434301	eval's multi_logloss: 1.89848	eval's map@3: 0.357538
# [600]	train's multi_logloss: 1.82215	train's map@3: 0.442906	eval's multi_logloss: 1.8967	eval's map@3: 0.35858
# [700]	train's multi_logloss: 1.81147	train's map@3: 0.449621	eval's multi_logloss: 1.89551	eval's map@3: 0.359934
# [800]	train's multi_logloss: 1.8014	train's map@3: 0.455733	eval's multi_logloss: 1.89477	eval's map@3: 0.361052
# [900]	train's multi_logloss: 1.79211	train's map@3: 0.461015	eval's multi_logloss: 1.89435	eval's map@3: 0.361722
# [1000]	train's multi_logloss: 1.78409	train's map@3: 0.465404	eval's multi_logloss: 1.89438	eval's map@3: 0.362303
# Early stopping, best iteration is:
# [925]	train's multi_logloss: 1.79002	train's map@3: 0.462114	eval's multi_logloss: 1.89423	eval's map@3: 0.362285
# Training time: 00:13:11
# Train map@3: 0.46211
# Valid map@3: 0.36229
# [I 2025-07-09 21:40:34,060] Trial 19 finished with value: 0.36228529411764704 and parameters: {'max_depth': 8, 'num_leaves': 755, 'min_child_samples': 13256, 'min_split_gain': 0.0016372592579610788, 'feature_fraction': 0.4088113318522991, 'bagging_fraction': 0.7693423542374184, 'bagging_freq': 10, 'lambda_l1': 0.0018936159696158652, 'lambda_l2': 7.400801335541301}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.9219	train's map@3: 0.327218	eval's multi_logloss: 1.92838	eval's map@3: 0.316812
# Early stopping, best iteration is:
# [94]	train's multi_logloss: 1.92192	train's map@3: 0.327293	eval's multi_logloss: 1.92838	eval's map@3: 0.316862
# Training time: 00:02:16
# Train map@3: 0.32729
# Valid map@3: 0.31686
# [I 2025-07-09 21:42:50,883] Trial 20 finished with value: 0.3168617647058823 and parameters: {'max_depth': 8, 'num_leaves': 664, 'min_child_samples': 12616, 'min_split_gain': 9.181861367591726, 'feature_fraction': 0.3683802233585493, 'bagging_fraction': 0.8850678485114325, 'bagging_freq': 3, 'lambda_l1': 0.14059878941559678, 'lambda_l2': 0.927461656334797}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90334	train's map@3: 0.357792	eval's multi_logloss: 1.91998	eval's map@3: 0.33176
# [200]	train's multi_logloss: 1.88136	train's map@3: 0.388132	eval's multi_logloss: 1.91161	eval's map@3: 0.342783
# [300]	train's multi_logloss: 1.86331	train's map@3: 0.409277	eval's multi_logloss: 1.90559	eval's map@3: 0.350095
# [400]	train's multi_logloss: 1.8473	train's map@3: 0.424418	eval's multi_logloss: 1.90116	eval's map@3: 0.355028
# [500]	train's multi_logloss: 1.83342	train's map@3: 0.435399	eval's multi_logloss: 1.89804	eval's map@3: 0.358166
# [600]	train's multi_logloss: 1.8213	train's map@3: 0.44423	eval's multi_logloss: 1.89592	eval's map@3: 0.360039
# [700]	train's multi_logloss: 1.81051	train's map@3: 0.451028	eval's multi_logloss: 1.89458	eval's map@3: 0.361445
# [800]	train's multi_logloss: 1.80042	train's map@3: 0.457379	eval's multi_logloss: 1.89366	eval's map@3: 0.36224
# [900]	train's multi_logloss: 1.79105	train's map@3: 0.462475	eval's multi_logloss: 1.89344	eval's map@3: 0.363289
# Early stopping, best iteration is:
# [854]	train's multi_logloss: 1.79527	train's map@3: 0.460195	eval's multi_logloss: 1.89338	eval's map@3: 0.362825
# Training time: 00:12:18
# Train map@3: 0.46020
# Valid map@3: 0.36282
# [I 2025-07-09 21:55:09,750] Trial 21 finished with value: 0.36282450980392156 and parameters: {'max_depth': 8, 'num_leaves': 755, 'min_child_samples': 13828, 'min_split_gain': 5.525376566465776e-05, 'feature_fraction': 0.3191684684164826, 'bagging_fraction': 0.8074047679425762, 'bagging_freq': 7, 'lambda_l1': 0.01206666264033529, 'lambda_l2': 0.24563922211857808}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90299	train's map@3: 0.358453	eval's multi_logloss: 1.91992	eval's map@3: 0.331118
# [200]	train's multi_logloss: 1.88089	train's map@3: 0.388508	eval's multi_logloss: 1.91152	eval's map@3: 0.342502
# [300]	train's multi_logloss: 1.86289	train's map@3: 0.408917	eval's multi_logloss: 1.9058	eval's map@3: 0.349922
# [400]	train's multi_logloss: 1.84695	train's map@3: 0.423835	eval's multi_logloss: 1.90154	eval's map@3: 0.35423
# [500]	train's multi_logloss: 1.83311	train's map@3: 0.43483	eval's multi_logloss: 1.89844	eval's map@3: 0.35726
# [600]	train's multi_logloss: 1.82091	train's map@3: 0.44371	eval's multi_logloss: 1.89638	eval's map@3: 0.359921
# [700]	train's multi_logloss: 1.81006	train's map@3: 0.450446	eval's multi_logloss: 1.89517	eval's map@3: 0.360656
# [800]	train's multi_logloss: 1.79999	train's map@3: 0.456223	eval's multi_logloss: 1.89443	eval's map@3: 0.361544
# [900]	train's multi_logloss: 1.7907	train's map@3: 0.461761	eval's multi_logloss: 1.89408	eval's map@3: 0.362387
# [1000]	train's multi_logloss: 1.7828	train's map@3: 0.466012	eval's multi_logloss: 1.89418	eval's map@3: 0.362583
# Early stopping, best iteration is:
# [932]	train's multi_logloss: 1.78811	train's map@3: 0.463205	eval's multi_logloss: 1.89403	eval's map@3: 0.362647
# Training time: 00:13:23
# Train map@3: 0.46320
# Valid map@3: 0.36265
# [I 2025-07-09 22:08:33,654] Trial 22 finished with value: 0.3626470588235294 and parameters: {'max_depth': 8, 'num_leaves': 633, 'min_child_samples': 11870, 'min_split_gain': 0.0043033358931702835, 'feature_fraction': 0.3702520388956333, 'bagging_fraction': 0.7021344467543813, 'bagging_freq': 4, 'lambda_l1': 0.0010009435849203752, 'lambda_l2': 0.03838321392976668}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90192	train's map@3: 0.359963	eval's multi_logloss: 1.91947	eval's map@3: 0.331856
# [200]	train's multi_logloss: 1.87898	train's map@3: 0.391422	eval's multi_logloss: 1.91083	eval's map@3: 0.344278
# [300]	train's multi_logloss: 1.86006	train's map@3: 0.412469	eval's multi_logloss: 1.90466	eval's map@3: 0.351177
# [400]	train's multi_logloss: 1.84356	train's map@3: 0.427491	eval's multi_logloss: 1.90032	eval's map@3: 0.356134
# [500]	train's multi_logloss: 1.82919	train's map@3: 0.438868	eval's multi_logloss: 1.89748	eval's map@3: 0.358938
# [600]	train's multi_logloss: 1.81675	train's map@3: 0.447205	eval's multi_logloss: 1.89554	eval's map@3: 0.360439
# [700]	train's multi_logloss: 1.80559	train's map@3: 0.454104	eval's multi_logloss: 1.89436	eval's map@3: 0.361798
# [800]	train's multi_logloss: 1.79512	train's map@3: 0.460337	eval's multi_logloss: 1.89378	eval's map@3: 0.36274
# [900]	train's multi_logloss: 1.78547	train's map@3: 0.465822	eval's multi_logloss: 1.89353	eval's map@3: 0.363304
# [1000]	train's multi_logloss: 1.7772	train's map@3: 0.470312	eval's multi_logloss: 1.89382	eval's map@3: 0.363893
# Early stopping, best iteration is:
# [918]	train's multi_logloss: 1.78389	train's map@3: 0.466514	eval's multi_logloss: 1.89351	eval's map@3: 0.363535
# Training time: 00:13:16
# Train map@3: 0.46651
# Valid map@3: 0.36354
# [I 2025-07-09 22:21:50,831] Trial 23 finished with value: 0.3635352941176471 and parameters: {'max_depth': 8, 'num_leaves': 691, 'min_child_samples': 11992, 'min_split_gain': 0.00045362835595995913, 'feature_fraction': 0.36165246059216205, 'bagging_fraction': 0.7512927330528155, 'bagging_freq': 4, 'lambda_l1': 0.0006823146798870703, 'lambda_l2': 0.028364028348042768}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.89973	train's map@3: 0.363628	eval's multi_logloss: 1.91896	eval's map@3: 0.332764
# [200]	train's multi_logloss: 1.87543	train's map@3: 0.395874	eval's multi_logloss: 1.90992	eval's map@3: 0.344803
# [300]	train's multi_logloss: 1.85553	train's map@3: 0.417376	eval's multi_logloss: 1.90384	eval's map@3: 0.352086
# [400]	train's multi_logloss: 1.83809	train's map@3: 0.432873	eval's multi_logloss: 1.89951	eval's map@3: 0.356413
# [500]	train's multi_logloss: 1.82305	train's map@3: 0.443866	eval's multi_logloss: 1.89661	eval's map@3: 0.358949
# [600]	train's multi_logloss: 1.80995	train's map@3: 0.452684	eval's multi_logloss: 1.8951	eval's map@3: 0.360341
# [700]	train's multi_logloss: 1.7983	train's map@3: 0.459553	eval's multi_logloss: 1.89421	eval's map@3: 0.361372
# [800]	train's multi_logloss: 1.78726	train's map@3: 0.466097	eval's multi_logloss: 1.89403	eval's map@3: 0.362341
# [900]	train's multi_logloss: 1.77713	train's map@3: 0.471321	eval's multi_logloss: 1.89404	eval's map@3: 0.36274
# Early stopping, best iteration is:
# [840]	train's multi_logloss: 1.78314	train's map@3: 0.467998	eval's multi_logloss: 1.89385	eval's map@3: 0.362925
# Training time: 00:12:22
# Train map@3: 0.46800
# Valid map@3: 0.36293
# [I 2025-07-09 22:34:14,043] Trial 24 finished with value: 0.36292549019607845 and parameters: {'max_depth': 8, 'num_leaves': 693, 'min_child_samples': 10881, 'min_split_gain': 0.000492903114167403, 'feature_fraction': 0.4120889745565063, 'bagging_fraction': 0.7545153114630025, 'bagging_freq': 2, 'lambda_l1': 0.007324465999130926, 'lambda_l2': 0.002984670120884234}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90158	train's map@3: 0.36105	eval's multi_logloss: 1.91953	eval's map@3: 0.331536
# [200]	train's multi_logloss: 1.87833	train's map@3: 0.392481	eval's multi_logloss: 1.91084	eval's map@3: 0.344249
# [300]	train's multi_logloss: 1.85933	train's map@3: 0.413301	eval's multi_logloss: 1.90474	eval's map@3: 0.350925
# [400]	train's multi_logloss: 1.84276	train's map@3: 0.428492	eval's multi_logloss: 1.90038	eval's map@3: 0.355701
# [500]	train's multi_logloss: 1.82843	train's map@3: 0.439382	eval's multi_logloss: 1.89736	eval's map@3: 0.358005
# [600]	train's multi_logloss: 1.81586	train's map@3: 0.447848	eval's multi_logloss: 1.89546	eval's map@3: 0.360049
# [700]	train's multi_logloss: 1.80463	train's map@3: 0.455018	eval's multi_logloss: 1.89452	eval's map@3: 0.361004
# [800]	train's multi_logloss: 1.79403	train's map@3: 0.461092	eval's multi_logloss: 1.8939	eval's map@3: 0.362016
# [900]	train's multi_logloss: 1.78433	train's map@3: 0.466653	eval's multi_logloss: 1.89383	eval's map@3: 0.362752
# Early stopping, best iteration is:
# [855]	train's multi_logloss: 1.78863	train's map@3: 0.46431	eval's multi_logloss: 1.89372	eval's map@3: 0.362051
# Training time: 00:12:29
# Train map@3: 0.46431
# Valid map@3: 0.36205
# [I 2025-07-09 22:46:43,987] Trial 25 finished with value: 0.3620509803921569 and parameters: {'max_depth': 8, 'num_leaves': 713, 'min_child_samples': 12352, 'min_split_gain': 5.515797175004575e-05, 'feature_fraction': 0.4315253536251258, 'bagging_fraction': 0.7841513795125689, 'bagging_freq': 5, 'lambda_l1': 0.0007320164889689089, 'lambda_l2': 0.021445947592109816}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.9027	train's map@3: 0.358467	eval's multi_logloss: 1.91971	eval's map@3: 0.33104
# [200]	train's multi_logloss: 1.88029	train's map@3: 0.389538	eval's multi_logloss: 1.91116	eval's map@3: 0.343036
# [300]	train's multi_logloss: 1.86188	train's map@3: 0.411007	eval's multi_logloss: 1.90509	eval's map@3: 0.350143
# [400]	train's multi_logloss: 1.84584	train's map@3: 0.42618	eval's multi_logloss: 1.90066	eval's map@3: 0.35487
# [500]	train's multi_logloss: 1.83177	train's map@3: 0.43727	eval's multi_logloss: 1.89743	eval's map@3: 0.358619
# [600]	train's multi_logloss: 1.8196	train's map@3: 0.445706	eval's multi_logloss: 1.89555	eval's map@3: 0.36013
# [700]	train's multi_logloss: 1.80864	train's map@3: 0.452817	eval's multi_logloss: 1.89439	eval's map@3: 0.361079
# [800]	train's multi_logloss: 1.7984	train's map@3: 0.458771	eval's multi_logloss: 1.89371	eval's map@3: 0.362328
# [900]	train's multi_logloss: 1.78885	train's map@3: 0.464167	eval's multi_logloss: 1.89352	eval's map@3: 0.363026
# Early stopping, best iteration is:
# [873]	train's multi_logloss: 1.79133	train's map@3: 0.462799	eval's multi_logloss: 1.89346	eval's map@3: 0.362996
# Training time: 00:12:57
# Train map@3: 0.46280
# Valid map@3: 0.36300
# [I 2025-07-09 22:59:41,565] Trial 26 finished with value: 0.36299607843137255 and parameters: {'max_depth': 8, 'num_leaves': 755, 'min_child_samples': 13998, 'min_split_gain': 0.0006121152406884019, 'feature_fraction': 0.3995702848997735, 'bagging_fraction': 0.8356919681476216, 'bagging_freq': 6, 'lambda_l1': 9.500273558691742e-05, 'lambda_l2': 0.15339347024763555}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.89966	train's map@3: 0.363382	eval's multi_logloss: 1.91888	eval's map@3: 0.332046
# [200]	train's multi_logloss: 1.8751	train's map@3: 0.396029	eval's multi_logloss: 1.90997	eval's map@3: 0.344852
# [300]	train's multi_logloss: 1.855	train's map@3: 0.417498	eval's multi_logloss: 1.9038	eval's map@3: 0.35176
# [400]	train's multi_logloss: 1.83753	train's map@3: 0.432749	eval's multi_logloss: 1.89975	eval's map@3: 0.356135
# [500]	train's multi_logloss: 1.82234	train's map@3: 0.443811	eval's multi_logloss: 1.89692	eval's map@3: 0.358589
# [600]	train's multi_logloss: 1.80927	train's map@3: 0.452529	eval's multi_logloss: 1.8954	eval's map@3: 0.360417
# [700]	train's multi_logloss: 1.79752	train's map@3: 0.459828	eval's multi_logloss: 1.89454	eval's map@3: 0.360985
# [800]	train's multi_logloss: 1.78653	train's map@3: 0.466159	eval's multi_logloss: 1.89409	eval's map@3: 0.362102
# [900]	train's multi_logloss: 1.77631	train's map@3: 0.471523	eval's multi_logloss: 1.89442	eval's map@3: 0.36258
# Early stopping, best iteration is:
# [820]	train's multi_logloss: 1.78444	train's map@3: 0.467062	eval's multi_logloss: 1.89407	eval's map@3: 0.362568
# Training time: 00:12:24
# Train map@3: 0.46706
# Valid map@3: 0.36257
# [I 2025-07-09 23:12:06,406] Trial 27 finished with value: 0.36256764705882355 and parameters: {'max_depth': 8, 'num_leaves': 666, 'min_child_samples': 10410, 'min_split_gain': 4.5432773439066416e-05, 'feature_fraction': 0.36678006399245255, 'bagging_fraction': 0.7341516872784438, 'bagging_freq': 8, 'lambda_l1': 0.0741442199907788, 'lambda_l2': 0.6679020132447163}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.90257	train's map@3: 0.358644	eval's multi_logloss: 1.91988	eval's map@3: 0.331456
# [200]	train's multi_logloss: 1.88012	train's map@3: 0.389742	eval's multi_logloss: 1.91136	eval's map@3: 0.34284
# [300]	train's multi_logloss: 1.86171	train's map@3: 0.410677	eval's multi_logloss: 1.90523	eval's map@3: 0.350165
# [400]	train's multi_logloss: 1.84563	train's map@3: 0.425487	eval's multi_logloss: 1.90106	eval's map@3: 0.353958
# [500]	train's multi_logloss: 1.83148	train's map@3: 0.436782	eval's multi_logloss: 1.89784	eval's map@3: 0.356786
# [600]	train's multi_logloss: 1.81928	train's map@3: 0.445451	eval's multi_logloss: 1.89587	eval's map@3: 0.359158
# [700]	train's multi_logloss: 1.80826	train's map@3: 0.452225	eval's multi_logloss: 1.89464	eval's map@3: 0.360411
# [800]	train's multi_logloss: 1.79791	train's map@3: 0.458158	eval's multi_logloss: 1.89392	eval's map@3: 0.361513
# [900]	train's multi_logloss: 1.7884	train's map@3: 0.463691	eval's multi_logloss: 1.89343	eval's map@3: 0.362377
# [1000]	train's multi_logloss: 1.78023	train's map@3: 0.46792	eval's multi_logloss: 1.89358	eval's map@3: 0.363045
# Early stopping, best iteration is:
# [928]	train's multi_logloss: 1.78599	train's map@3: 0.464977	eval's multi_logloss: 1.89337	eval's map@3: 0.362542
# Training time: 00:13:26
# Train map@3: 0.46498
# Valid map@3: 0.36254
# [I 2025-07-09 23:25:33,775] Trial 28 finished with value: 0.3625421568627451 and parameters: {'max_depth': 8, 'num_leaves': 741, 'min_child_samples': 12717, 'min_split_gain': 0.005489571555811632, 'feature_fraction': 0.3198347418286747, 'bagging_fraction': 0.7658134219178817, 'bagging_freq': 4, 'lambda_l1': 0.00828854942467411, 'lambda_l2': 0.021053397870383555}. Best is trial 14 with value: 0.36363529411764706.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.89779	train's map@3: 0.366386	eval's multi_logloss: 1.91796	eval's map@3: 0.334232
# [200]	train's multi_logloss: 1.87162	train's map@3: 0.400717	eval's multi_logloss: 1.90817	eval's map@3: 0.347461
# [300]	train's multi_logloss: 1.85051	train's map@3: 0.422886	eval's multi_logloss: 1.90192	eval's map@3: 0.354003
# [400]	train's multi_logloss: 1.83223	train's map@3: 0.43831	eval's multi_logloss: 1.89781	eval's map@3: 0.358491
# [500]	train's multi_logloss: 1.81658	train's map@3: 0.449574	eval's multi_logloss: 1.89536	eval's map@3: 0.360709
# [600]	train's multi_logloss: 1.80284	train's map@3: 0.458323	eval's multi_logloss: 1.89381	eval's map@3: 0.3621
# [700]	train's multi_logloss: 1.79063	train's map@3: 0.465574	eval's multi_logloss: 1.89308	eval's map@3: 0.363086
# [800]	train's multi_logloss: 1.77912	train's map@3: 0.47219	eval's multi_logloss: 1.89294	eval's map@3: 0.363864
# Early stopping, best iteration is:
# [734]	train's multi_logloss: 1.78641	train's map@3: 0.46823	eval's multi_logloss: 1.89283	eval's map@3: 0.363757
# Training time: 00:11:11
# Train map@3: 0.46823
# Valid map@3: 0.36376
# [I 2025-07-09 23:36:46,262] Trial 29 finished with value: 0.363756862745098 and parameters: {'max_depth': 8, 'num_leaves': 685, 'min_child_samples': 11410, 'min_split_gain': 0.0003966604647059324, 'feature_fraction': 0.3779493566383462, 'bagging_fraction': 0.8645455500650421, 'bagging_freq': 2, 'lambda_l1': 0.0017447313907056376, 'lambda_l2': 1.8325349971546228}. Best is trial 29 with value: 0.363756862745098.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.89407	train's map@3: 0.372128	eval's multi_logloss: 1.91683	eval's map@3: 0.335841
# [200]	train's multi_logloss: 1.86516	train's map@3: 0.408764	eval's multi_logloss: 1.90681	eval's map@3: 0.348804
# [300]	train's multi_logloss: 1.84184	train's map@3: 0.431384	eval's multi_logloss: 1.90045	eval's map@3: 0.355601
# [400]	train's multi_logloss: 1.82166	train's map@3: 0.44772	eval's multi_logloss: 1.8965	eval's map@3: 0.359251
# [500]	train's multi_logloss: 1.80441	train's map@3: 0.459411	eval's multi_logloss: 1.89413	eval's map@3: 0.362223
# [600]	train's multi_logloss: 1.7894	train's map@3: 0.4686	eval's multi_logloss: 1.89305	eval's map@3: 0.36276
# [700]	train's multi_logloss: 1.77594	train's map@3: 0.476294	eval's multi_logloss: 1.89288	eval's map@3: 0.363686
# [800]	train's multi_logloss: 1.76322	train's map@3: 0.483009	eval's multi_logloss: 1.89284	eval's map@3: 0.364418
# Early stopping, best iteration is:
# [729]	train's multi_logloss: 1.77193	train's map@3: 0.478612	eval's multi_logloss: 1.89272	eval's map@3: 0.363896
# Training time: 00:10:38
# Train map@3: 0.47861
# Valid map@3: 0.36390
# [I 2025-07-09 23:47:25,435] Trial 30 finished with value: 0.36389607843137256 and parameters: {'max_depth': 8, 'num_leaves': 621, 'min_child_samples': 9729, 'min_split_gain': 0.0008793022734111571, 'feature_fraction': 0.3514478163144178, 'bagging_fraction': 0.8842473071543802, 'bagging_freq': 2, 'lambda_l1': 0.00026003894788305436, 'lambda_l2': 2.112199050376843}. Best is trial 30 with value: 0.36389607843137256.
# Training until validation scores don't improve for 100 rounds
# [100]	train's multi_logloss: 1.89385	train's map@3: 0.372471	eval's multi_logloss: 1.91701	eval's map@3: 0.3359
# [W 2025-07-09 23:50:05,137] Trial 31 failed with parameters: {'max_depth': 8, 'num_leaves': 636, 'min_child_samples': 9559, 'min_split_gain': 0.002791209213101816, 'feature_fraction': 0.3201058498531959, 'bagging_fraction': 0.8680221528379002, 'bagging_freq': 2, 'lambda_l1': 4.0698458595891705e-05, 'lambda_l2': 2.868128047832402} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\Users\hanse\anaconda3\Lib\site-packages\optuna\study\_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\hanse\kaggle\fertilizer\src\models\lgb\lgb_optuna_optimizer.py", line 50, in objective
#     trainer.fit_one_fold(tr_df, fold=0)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\hanse\kaggle\fertilizer\src\models\lgb\lgb_cv_trainer.py", line 276, in fit_one_fold
#     dvalid = lgb.Dataset(X_val, label=y_val, reference=dtrain)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#             lgb.early_stopping(stopping_rounds=self.early_stopping_rounds),
#
#   File "C:\Users\hanse\anaconda3\Lib\site-packages\lightgbm\engine.py", line 328, in train
#     evaluation_result_list.extend(booster.eval_train(feval))
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\hanse\anaconda3\Lib\site-packages\lightgbm\basic.py", line 4408, in eval_train
#     return self.__inner_eval(self._train_data_name, 0, feval)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hanse\anaconda3\Lib\site-packages\lightgbm\basic.py", line 5206, in __inner_eval
#     feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#   File "C:\Users\hanse\kaggle\fertilizer\src\models\lgb\lgb_cv_trainer.py", line 59, in _map3eval
#     map3 = np.mean([apk(a, p) for a, p in zip(y_true, top3)])
#                     ~~~^^^^^^
# KeyboardInterrupt
# [W 2025-07-09 23:50:05,144] Trial 31 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#       5 objective = op.create_objective(
#       6     tr_df4,
#       7     early_stopping_rounds=100,
#       8     cat_cols=cat_cols,
#       9     n_jobs=25
#      10 )
#      12 random_sampler = optuna.samplers.RandomSampler(seed=42)
# ---> 14 study = op.run_optuna_search(
#      15     objective,
#      16     n_trials=30,
#      17     n_jobs=1,
#      18     study_name="lgb_v4",
#      19     storage=storage,
#      20     # initial_params=params
#      21 )
#
# File ~\kaggle\fertilizer\src\models\lgb\lgb_optuna_optimizer.py:80, in run_optuna_search(objective, n_trials, n_jobs, study_name, storage, initial_params, sampler)
#      77 if initial_params is not None:
#      78     study.enqueue_trial(initial_params)
# ---> 80 study.optimize(
#      81     objective,
#      82     n_trials=n_trials,
#      83     n_jobs=n_jobs,
#      84     show_progress_bar=True
#      85 )
#      87 return study
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:489, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     387 def optimize(
#     388     self,
#     389     func: ObjectiveFuncType,
#    (...)
#     396     show_progress_bar: bool = False,
#     397 ) -> None:
#     398     """Optimize an objective function.
#     399
#     400     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     487             If nested invocation of this method occurs.
#     488     """
# --> 489     _optimize(
#     490         study=self,
#     491         func=func,
#     492         n_trials=n_trials,
#     493         timeout=timeout,
#     494         n_jobs=n_jobs,
#     495         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     496         callbacks=callbacks,
#     497         gc_after_trial=gc_after_trial,
#     498         show_progress_bar=show_progress_bar,
#     499     )
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:64, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      62 try:
#      63     if n_jobs == 1:
# ---> 64         _optimize_sequential(
#      65             study,
#      66             func,
#      67             n_trials,
#      68             timeout,
#      69             catch,
#      70             callbacks,
#      71             gc_after_trial,
#      72             reseed_sampler_rng=False,
#      73             time_start=None,
#      74             progress_bar=progress_bar,
#      75         )
#      76     else:
#      77         if n_jobs == -1:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:161, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158         break
#     160 try:
# --> 161     frozen_trial = _run_trial(study, func, catch)
#     162 finally:
#     163     # The following line mitigates memory problems that can be occurred in some
#     164     # environments (e.g., services that use computing containers such as GitHub Actions).
#     165     # Please refer to the following PR for further details:
#     166     # https://github.com/optuna/optuna/pull/325.
#     167     if gc_after_trial:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:253, in _run_trial(study, func, catch)
#     246         assert False, "Should not reach."
#     248 if (
#     249     frozen_trial.state == TrialState.FAIL
#     250     and func_err is not None
#     251     and not isinstance(func_err, catch)
#     252 ):
# --> 253     raise func_err
#     254 return frozen_trial
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# File ~\kaggle\fertilizer\src\models\lgb\lgb_optuna_optimizer.py:50, in create_objective.<locals>.objective(trial)
#      43 trainer = LGBCVTrainer(
#      44     params=params,
#      45     n_splits=n_splits,
#      46     early_stopping_rounds=early_stopping_rounds
#      47 )
#      48 trainer.categorical_features = cat_cols or []
# ---> 50 trainer.fit_one_fold(tr_df, fold=0)
#      52 best_iteration = trainer.fold_models[0].model.best_iteration
#      53 trial.set_user_attr("best_iteration", best_iteration)
#
# File ~\kaggle\fertilizer\src\models\lgb\lgb_cv_trainer.py:276, in fit_one_fold(self, tr_df, fold)
#     269 X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]
#     271 dtrain = lgb.Dataset(
#     272     X_tr, label=y_tr,
#     273     categorical_feature=valid_categorical,
#     274     weight=w_tr)
# --> 276 dvalid = lgb.Dataset(X_val, label=y_val, reference=dtrain)
#     278 evals_result = {}
#     280 model = lgb.train(
#     281     self.params,
#     282     dtrain,
#    (...)
#     291     ]
#     292 )
#
# File ~\anaconda3\Lib\site-packages\lightgbm\engine.py:328, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     326 if valid_sets is not None:
#     327     if is_valid_contain_train:
# --> 328         evaluation_result_list.extend(booster.eval_train(feval))
#     329     evaluation_result_list.extend(booster.eval_valid(feval))
#     330 try:
#
# File ~\anaconda3\Lib\site-packages\lightgbm\basic.py:4408, in Booster.eval_train(self, feval)
#    4376 def eval_train(
#    4377     self,
#    4378     feval: Optional[Union[_LGBM_CustomEvalFunction, List[_LGBM_CustomEvalFunction]]] = None,
#    4379 ) -> List[_LGBM_BoosterEvalMethodResultType]:
#    4380     """Evaluate for training data.
#    4381
#    4382     Parameters
#    (...)
#    4406         List with (train_dataset_name, eval_name, eval_result, is_higher_better) tuples.
#    4407     """
# -> 4408     return self.__inner_eval(self._train_data_name, 0, feval)
#
# File ~\anaconda3\Lib\site-packages\lightgbm\basic.py:5206, in Booster.__inner_eval(self, data_name, data_idx, feval)
#    5204 if eval_function is None:
#    5205     continue
# -> 5206 feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#    5207 if isinstance(feval_ret, list):
#    5208     for eval_name, val, is_higher_better in feval_ret:
#
# File ~\kaggle\fertilizer\src\models\lgb\lgb_cv_trainer.py:59, in LGBCVTrainer._map3eval(self, preds, dtrain)
#      56             return 1.0 / (i + 1)
#      57     return 0.0
# ---> 59 map3 = np.mean([apk(a, p) for a, p in zip(y_true, top3)])
#      60 return 'map@3', map3, True
#
# KeyboardInterrupt:

# %%
# 16のfull train
params = {
    "max_depth": 8,
    "num_leaves": 621,
    "min_child_samples": 9729,
    "min_split_gain": 0.0008793022734111571,
    "feature_fraction": 0.3514478163144178,
    "bagging_fraction": 0.8842473071543802,
    "bagging_freq": 2,
    "lambda_l1": 0.00026003894788305436,
    "lambda_l2": 2.112199050376843
}

trainer = cv.LGBCVTrainer(params=params, cat_cols=cat_cols)
trainer.full_train(tr_df4, test_df4, 851, 16)
# Out:
# Training time: 00:18:46
# Successfully saved test predictions to ../artifacts/test_preds/full/test_full_16.npy
